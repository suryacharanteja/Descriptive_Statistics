# %% [markdown]
# # Data sorting

# %%
numbers = [5, 2, 8, 1, 9, 3]

sorted_numbers = sorted(numbers)

print("Sorted numbers in ascending oreder:", sorted_numbers)
# Out:
# Sorted numbers in ascending oreder: [1, 2, 3, 5, 8, 9]

# %%
# example of sorting a list of strings in descending order:

fruits = ['apple', 'banana', 'cherry', 'date', 'fig']

sorted_fruits = sorted(fruits, reverse=True)
print("Sorted fruits in descending order:", sorted_fruits)
# Out:
# Sorted fruits in descending order: ['fig', 'date', 'cherry', 'banana', 'apple']

# %%
# sorting a DataFrame by a single Column:
import pandas as pd

# create a sample DataFrame
df = pd.DataFrame({'Name': ['Charan', 'Kiran', 'Surya', 'Divya', 'Daksha'], 'Age': [25, 30, 22, 35, 28], 'City': ['Bengaluru', 'Vishakapatnam', 'Chennai', 'Mumbai', 'Kolkata']})

# sort the DataFrame by the 'Age' column in ascending order
df_sorted = df.sort_values('Age', ascending=True)

# %%
df
# Out:
#      Name  Age           City
# 0  Charan   25      Bengaluru
# 1   Kiran   30  Vishakapatnam
# 2   Surya   22        Chennai
# 3   Divya   35         Mumbai
# 4  Daksha   28        Kolkata

# %%
df_sorted
# Out:
#      Name  Age           City
# 2   Surya   22        Chennai
# 0  Charan   25      Bengaluru
# 4  Daksha   28        Kolkata
# 1   Kiran   30  Vishakapatnam
# 3   Divya   35         Mumbai

# %%
# sort the 'Age' column in descending order, 'Name' in ascending order
df_sorted2 = df.sort_values(by= ['Age', 'Name'], ascending=[False, True])

# %%
df_sorted2
# Out:
#      Name  Age           City
# 3   Divya   35         Mumbai
# 1   Kiran   30  Vishakapatnam
# 4  Daksha   28        Kolkata
# 0  Charan   25      Bengaluru
# 2   Surya   22        Chennai

# %%
# sorting a DataFrame by index

df_sortedI = df.sort_index(ascending=False)

# %%
df_sortedI
# Out:
#      Name  Age           City
# 4  Daksha   28        Kolkata
# 3   Divya   35         Mumbai
# 2   Surya   22        Chennai
# 1   Kiran   30  Vishakapatnam
# 0  Charan   25      Bengaluru

# %%
units = pd.read_csv("./unit _sales_data.csv")

# %%
units
# Out:
#     Month  Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0     1.0     73959.0       8.75          50.04            61.13
# 1     2.0     71544.0       8.99          50.74            60.19
# 2     3.0     78587.0       7.50          50.14            59.16
# 3     4.0     80364.0       7.25          50.27            60.38
# 4     5.0     78771.0       7.40          51.25            59.71
# 5     6.0     71986.0       8.50          50.65            59.88
# 6     7.0     74885.0       8.40          50.87            60.14
# 7     8.0     73345.0       7.90          50.15            60.08
# 8     9.0     76659.0       7.25          48.24            59.90
# 9    10.0     71880.0       8.70          50.19            59.68
# 10   11.0     73598.0       8.40          51.11            59.83
# 11   12.0     74893.0       8.10          51.49            59.77
# 12   13.0     69003.0       8.40          50.10            59.29
# ...

# %%
units_sorted = units.sort_values(by="Promexp ('000$)", ascending=False)

# %%
units.columns
# Out:
# Index(['Month', 'Unit Sales', 'Price ($)', 'Adexp ('000$)', 'Promexp ('000$)'], dtype='object')

# %%
units_sorted
# Out:
#     Month  Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0     1.0     73959.0       8.75          50.04            61.13
# 19   20.0     76200.0       7.99          49.00            61.00
# 16   17.0     76253.0       8.10          51.62            60.51
# 23   24.0     75643.0       8.25          50.00            60.50
# 13   14.0     78542.0       7.40          49.24            60.40
# 3     4.0     80364.0       7.25          50.27            60.38
# 1     2.0     71544.0       8.99          50.74            60.19
# 6     7.0     74885.0       8.40          50.87            60.14
# 18   19.0     69022.0       8.99          48.60            60.09
# 7     8.0     73345.0       7.90          50.15            60.08
# 15   16.0     74247.0       8.30          49.46            60.06
# 8     9.0     76659.0       7.25          48.24            59.90
# 14   15.0     72543.0       8.00          50.04            59.89
# ...

# %%
units_sortedMS = units.sort_values(by=["Promexp ('000$)", 'Month'], ascending=[False, True])

# %%
units_sortedMS
# Out:
#     Month  Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0     1.0     73959.0       8.75          50.04            61.13
# 19   20.0     76200.0       7.99          49.00            61.00
# 16   17.0     76253.0       8.10          51.62            60.51
# 23   24.0     75643.0       8.25          50.00            60.50
# 13   14.0     78542.0       7.40          49.24            60.40
# 3     4.0     80364.0       7.25          50.27            60.38
# 1     2.0     71544.0       8.99          50.74            60.19
# 6     7.0     74885.0       8.40          50.87            60.14
# 18   19.0     69022.0       8.99          48.60            60.09
# 7     8.0     73345.0       7.90          50.15            60.08
# 15   16.0     74247.0       8.30          49.46            60.06
# 8     9.0     76659.0       7.25          48.24            59.90
# 14   15.0     72543.0       8.00          50.04            59.89
# ...

# %%
units_sortedMS1 = units.sort_values(by=['Month', "Promexp ('000$)"], ascending=[True, False])

# %%
units_sortedMS1
# Out:
#     Month  Unit Sales  Price ($)  Adexp ('000$)  Promexp ('000$)
# 0     1.0     73959.0       8.75          50.04            61.13
# 1     2.0     71544.0       8.99          50.74            60.19
# 2     3.0     78587.0       7.50          50.14            59.16
# 3     4.0     80364.0       7.25          50.27            60.38
# 4     5.0     78771.0       7.40          51.25            59.71
# 5     6.0     71986.0       8.50          50.65            59.88
# 6     7.0     74885.0       8.40          50.87            60.14
# 7     8.0     73345.0       7.90          50.15            60.08
# 8     9.0     76659.0       7.25          48.24            59.90
# 9    10.0     71880.0       8.70          50.19            59.68
# 10   11.0     73598.0       8.40          51.11            59.83
# 11   12.0     74893.0       8.10          51.49            59.77
# 12   13.0     69003.0       8.40          50.10            59.29
# ...

# %% [markdown]
# # Data categorization

# %%
# example of categorizing data into bins or categories

ages = [22, 34, 45, 56, 67, 78, 89, 90, 95, 100]

age_bins = []

for age in ages:
    if age < 30:
        age_bins.append('20s')
    elif age < 40:
        age_bins.append('30s')
    elif age < 50:
        age_bins.append('40s')
    else:
        age_bins.append('50s+')
print("Age bins:", age_bins)
# Out:
# Age bins: ['20s', '30s', '40s', '50s+', '50s+', '50s+', '50s+', '50s+', '50s+', '50s+']

# %%
# categorizing the data using 'cut()' method
df = pd.DataFrame({'Age': [25, 30, 45, 35, 28], 'Income': [50000, 60000, 55000, 70000, 65000]})

# define binds and labels for categorization
bins = [20, 30, 40, 50]
labels = ['20-29', '30-39', '40-49']

# add a new column 'Age Group' to DataFrame based on the 'Age' column values
df["Age Group"] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df
# Out:
#    Age  Income Age Group
# 0   25   50000     20-29
# 1   30   60000     20-29
# 2   45   55000     40-49
# 3   35   70000     30-39
# 4   28   65000     20-29

# %%
players = pd.read_csv("./Soccer_players_data1.csv")

# define binds and labels for categorization
bins = [30, 50, 80, 120, 218]
labels = ['Lean', 'Normal', 'Fat', 'Obese']

# let us create a pandas series
Weight_groups = pd.cut(players['Weight(kg)'], bins=bins, labels=labels)
players['Weight_groups'] = Weight_groups

# %%
Weight_groups
# Out:
# 0       Normal
# 1       Normal
# 2       Normal
# 3       Normal
# 4       Normal
#          ...
# 1582       Fat
# 1583       Fat
# 1584    Normal
# 1585    Normal
# 1586       Fat
# Name: Weight(kg), Length: 1587, dtype: category
# Categories (4, object): ['Lean' < 'Normal' < 'Fat' < 'Obese']

# %%
Weight_groups.unique()
# Out:
# ['Normal', 'Lean', 'Fat', 'Obese', NaN]
# Categories (4, object): ['Lean' < 'Normal' < 'Fat' < 'Obese']

# %%
players
# Out:
#       Second name First name Gender  Height(cm)  Weight(kg)  \
# 0          Abbadi     Ilyas       M         170          69
# 1          Abbate    Simona       W         171          64
# 2        Abdelaal    Hesham       M         167          52
# 3     Abdulrahman      Amer       M         168          68
# 4           Abian     Pablo       M         177          78
# ...           ...        ...    ...         ...         ...
# 1582         Zhou      Peng       M         183          88
# 1583     Zlokovic     Boris       M         197         100
# 1584       Zolnir     Urska       W         173          63
# 1585        Zoric   Milenko       M         179          73
# 1586        Zugaj     Nenad       M         177          84
#
#               Country/Team Weight_groups
# 0                  Algeria        Normal
# 1                    Italy        Normal
# 2                    Egypt        Normal
# 3     United Arab Emirates        Normal
# ...

# %%
# categorize data using "qcut()"

# let us create a simple DataFrame
df1 = pd.DataFrame({'Income': [50000, 60000, 55000, 70000, 65000]})

# define quantiles and leabels for categorization
quantiles = [0, 0.25, 0.5, 0.75, 1]
labels = ['Q1', 'Q2', 'Q3', 'Q4']

# Add a new column "Income quantile" to DataFrame based on the "income " column
df1["Income quantile"] = pd.qcut(df["Income"], q=quantiles, labels=labels)
print(df1)
# Out:
#    Income Income quantile
# 0   50000              Q1
# 1   60000              Q2
# 2   55000              Q1
# 3   70000              Q4
# 4   65000              Q3

# %%
# categorizing Data using "map()" function

df = pd.DataFrame({'Gender': ['Male', 'Female', 'Male', 'Female', 'Male']})

# Define mapping of values to categories
gender_map = {'Male': 'M', "Female": 'F'}

# add a new column "Gender Short" to DataFrame by mapping values from 'Gender'
df["Gender_Short"] = df['Gender'].map(gender_map)

print(df)
# Out:
#    Gender Gender_Short
# 0    Male            M
# 1  Female            F
# 2    Male            M
# 3  Female            F
# 4    Male            M

# %% [markdown]
# # 3. Data Tabulation

# %%
# let us create a frequency table using pandas
data = {'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'], 'Age': [25, 30, 22, 35, 28, 29, 17, 31], 'City': ['Bengaluru', 'Moscow', 'Delhi', 'Vizag', 'Chennai', 'Mumbai', 'Delhi', 'Sri nagar']}

dft = pd.DataFrame(data)

# create a frequency table of Gender
gender_freq = dft["Gender"].value_counts()
print("Frequncy table of Gender:\n", gender_freq)

# create a contindency table of Gender vs City
gender_city_ct = pd.crosstab(dft['Gender'], dft['City'])
print("Contingency table of Gender vs. City:\n", gender_city_ct)
# Out:
# Frequncy table of Gender:
#  Male      4
# Female    4
# Name: Gender, dtype: int64
# Contingency table of Gender vs. City:
#  City    Bengaluru  Chennai  Delhi  Moscow  Mumbai  Sri nagar  Vizag
# Gender
# Female          0        0      0       1       1          1      1
# Male            1        1      2       0       0          0      0

# %%
dft
# Out:
#    Gender  Age       City
# 0    Male   25  Bengaluru
# 1  Female   30     Moscow
# 2    Male   22      Delhi
# 3  Female   35      Vizag
# 4    Male   28    Chennai
# 5  Female   29     Mumbai
# 6    Male   17      Delhi
# 7  Female   31  Sri nagar

# %% [markdown]
# ### 3.1 Frequency Distribution

# %%
# frequency distribution of a single column

# create a sample dataframe
dffd = pd.DataFrame({'Age': [25, 30, 22, 35, 28, 30, 35, 30, 22, 25, 22, 28]})

# calculate the frequency distribution of 'age' column
freq_dist = dffd['Age'].value_counts()

print(freq_dist)
# Out:
# 30    3
# 22    3
# 25    2
# 35    2
# 28    2
# Name: Age, dtype: int64

# %%
# frequency distribution of multiple columns

# create dataframe
dffdm = pd.DataFrame({'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'], 'Age': [25, 30, 22, 35, 28]})

# calculate frequency distribution of 'Gender' and 'Age' columns
freq_dist_gender = dffdm['Gender'].value_counts()
freq_dist_age = dffdm['Age'].value_counts()

print(freq_dist_gender)
print(freq_dist_age)
# Out:
# Male      3
# Female    2
# Name: Gender, dtype: int64
# 25    1
# 30    1
# 22    1
# 35    1
# 28    1
# Name: Age, dtype: int64

# %% [markdown]
# ### 3.2 relative frequency distribution

# %%
dfrfd = pd.DataFrame({'Age': [25, 30, 22, 35, 28, 30, 35, 30, 22, 25, 22, 28]})

# calculate the relative frequency distribution of 'Age' column

rel_freq_dist = dfrfd["Age"].value_counts(normalize=True)

print(rel_freq_dist)
# Out:
# 30    0.250000
# 22    0.250000
# 25    0.166667
# 35    0.166667
# 28    0.166667
# Name: Age, dtype: float64

# %% [markdown]
# ### 3.3 grouped relative frequency distribution

# %%
import numpy as np

dfgrfd = pd.DataFrame({'Age': [25, 30, 22, 35, 28, 30, 35, 30, 22, 25, 22, 28]})

# define the bin edges fro grouping the data
bin_edges = [20, 25, 30, 35, 40]

# group the data into bins and calculate the relative frequencies
age_bins = pd.cut(dfgrfd['Age'], bins=bin_edges)
grp_rel_freq_dist = age_bins.value_counts(normalize=True, sort=False)

print(grp_rel_freq_dist)
# Out:
# (20, 25]    0.416667
# (25, 30]    0.416667
# (30, 35]    0.166667
# (35, 40]    0.000000
# Name: Age, dtype: float64

# %%
dfsl = pd.DataFrame({'Scores': [68, 72, 83, 75, 90, 85, 77, 78, 89, 92,
                               76, 81, 84, 87, 88, 95, 96, 99, 100, 72,
                               68, 76, 82, 79, 74, 87, 91, 93, 97, 98]})

# %% [markdown]
# ### 3.4 stem and lead plot

# %%
dfsl = pd.DataFrame({'Scores': [68, 72, 83, 75, 90, 85, 77, 78, 89, 92,
                               76, 81, 84, 87, 88, 95, 96, 99, 100, 72,
                               68, 76, 82, 79, 74, 87, 91, 93, 97, 98]})
# extract the tens digit (stem) and unit digit (leaf) of the scores
dfsl['stem'] = dfsl['Scores'] // 10
dfsl['Leaf'] = dfsl['Scores'] % 10

# create a "stem and leaf" plot using pandas 'group by' and 'agg' functions
stem_and_leaf_plot = dfsl.groupby('stem')['Leaf'].agg(list)

print(stem_and_leaf_plot)
# Out:
# stem
# 6                          [8, 8]
# 7     [2, 5, 7, 8, 6, 2, 6, 9, 4]
# 8     [3, 5, 9, 1, 4, 7, 8, 2, 7]
# 9     [0, 2, 5, 6, 9, 1, 3, 7, 8]
# 10                            [0]
# Name: Leaf, dtype: object

# %% [markdown]
# # 4. Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# example of creating a bar chart of categorical data using matplotilb
fruits = ['apple', 'banana', 'cherry', 'date', 'fig']

fruit_counts = [12, 20, 8, 15, 10]

plt.bar(fruits, fruit_counts)

plt.xlabel("Fruit")
plt.ylabel("Count")

plt.title("Fruit Counts")

plt.show()

# %% [markdown]
# ### 4.1 histogram

# %%
dfhg = pd.DataFrame({'Scores': [68, 72, 83, 75, 90, 85, 77, 78, 89, 92,
                               76, 81, 84, 87, 88, 95, 96, 99, 100, 72,
                               68, 76, 82, 79, 74, 87, 91, 93, 97, 98]})

import matplotlib.pyplot as plt
import pandas as pd

# create a histogram using matplotlib
plt.hist(dfhg['Scores'], bins=10, edgecolor='black')
plt.xlabel("Exam Scores")
plt.ylabel("Frequency")
plt.title("Histogram of Exam Scores")

plt.show()
