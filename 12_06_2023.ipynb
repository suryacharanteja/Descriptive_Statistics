# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 10)

# %%
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
x.ndim
# Out:
# 1

# %%
y = 2 ** x

# %%
y
# Out:
# array([1.00000000e+00, 2.16011948e+00, 4.66611616e+00, 1.00793684e+01,
#        2.17726400e+01, 4.70315038e+01, 1.01593667e+02, 2.19454460e+02,
#        4.74047853e+02, 1.02400000e+03])

# %%
plt.plot(x, y)

# %%
y2 = np.log10(x)
# Out:
# C:\Users\Surya Charan Teja\AppData\Local\Temp\ipykernel_2816\1070364149.py:1: RuntimeWarning: divide by zero encountered in log10
#   y2 = np.log10(x)

# %%
y
# Out:
# array([1.00000000e+00, 2.16011948e+00, 4.66611616e+00, 1.00793684e+01,
#        2.17726400e+01, 4.70315038e+01, 1.01593667e+02, 2.19454460e+02,
#        4.74047853e+02, 1.02400000e+03])

# %%
plt.plot(x, y2)
